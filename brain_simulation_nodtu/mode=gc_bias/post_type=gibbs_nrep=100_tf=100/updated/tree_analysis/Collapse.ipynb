# %%
library(ggplot2)
library(dplyr)
f1 <- "/fs/cbcb-lab/rob/students/noor/Uncertainity/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/out_no_eqclass/1_1/collapsed.log"
f2 <- "/fs/cbcb-lab/rob/students/noor/Uncertainity/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/out_term_hirak/1_1/collapsed.log"
f3 <- "/fs/cbcb-lab/rob/students/noor/Uncertainity/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/out_term/1_1/collapsed.log"
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df1 <- read.delim(f1, header = F)
df2 <- read.delim(f2, header = F)
df3 <- read.delim(f3, header = F)

# %% [markdown]
# #### No Eq Class

# %%
ggplot() +
    geom_hex(data=df1, aes(x=1:nrow(df1), y=V5))
# Out:
# plot without title

# %% [markdown]
# #### Original Terminus

# %%
ggplot() +
    geom_hex(data=df2, aes(x=1:nrow(df2), y=V5))
# Out:
# plot without title

# %% [markdown]
# #### TreeTerminus

# %%
ggplot() +
    geom_hex(data=df3, aes(x=1:nrow(df3), y=V5))
# Out:
# plot without title

# %%
dim(df1)
dim(df2)
dim(df3)
# Out:
# [1] 9563    6
# [1] 7807    5
# [1] 70819     5

# %%
summary(df1$V5)
summary(df2$V5)
summary(df3$V5)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -1011.280   -11.106    -6.933   -10.572    -5.086    -3.940
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -1011.280   -12.090    -7.540   -11.423    -5.342    -3.941
#       Min.    1st Qu.     Median       Mean    3rd Qu.       Max.
# -1011.2799    -1.7017    -0.3004    -1.7956     0.0426    11.5336

# %%
summary(df1)

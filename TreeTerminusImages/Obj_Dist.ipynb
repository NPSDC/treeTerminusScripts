# %%
setwd('/fs/cbcb-lab/rob/students/noor/Uncertainity/treeTerminusScripts')

suppressPackageStartupMessages(source("tree_helper_function.R"))
suppressPackageStartupMessages(source("old_terminus_helper.R"))

suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(ggpubr))
suppressPackageStartupMessages(library(latex2exp))

# %%
dir <- "environment/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfDe.RData"))
size <- 20
dfDep <- dfDepth
pBrNorm <- ggplot(dfDepth, aes(x=log2(depthObj), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimNorm Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/brain_sim_nodtu_lowfc/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfDe.RData"))
size <- 20
pBrLow <- ggplot(dfDepth, aes(x=log2(depthObj), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimLow Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/Chimp/mode=gcbias/post_type=gibbs_nrep=100_tf=100/tree_analysis"
load(file.path(dir, "dfDe.RData"))
size <- 20
pChimp <- ggplot(dfDepth, aes(x=log2(depthObj), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("ChimpBrain Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/real_datasets/GSE100505/mode_gcbias=True/posttype=gibbs_npost=100_tf=100/comp_trees"
load(file.path(dir, "dfDe.RData"))
size <- 20
pMouse <- ggplot(dfDepth, aes(x=log2(depthObj), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("MouseMuscle Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

# %%
options(repr.plot.width=20, repr.plot.height=10)
ggarrange(pBrNorm,pBrLow,pMouse,pChimp, common.legend=T)
# Out:
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# plot without title

# %%
dir <- "environment/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
dfDep <- dfDepth
pBrNorm <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimNorm Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/brain_sim_nodtu_lowfc/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
pBrLow <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimLow Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/Chimp/mode=gcbias/post_type=gibbs_nrep=100_tf=100/tree_analysis"
load(file.path(dir, "dfLL.RData"))
size <- 20
pChimp <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("ChimpBrain Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/real_datasets/GSE100505/mode_gcbias=True/posttype=gibbs_npost=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
pMouse <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("MouseMuscle Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

# %%
options(repr.plot.width=20, repr.plot.height=10)
ggarrange(pBrNorm,pBrLow,pMouse,pChimp, common.legend=T)
# Out:
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# plot without title

# %%
dir <- "environment/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
pBrNorm <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimNorm Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/brain_sim_nodtu_lowfc/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
pBrLow <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimLow Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/Chimp/mode=gcbias/post_type=gibbs_nrep=100_tf=100/tree_analysis"
load(file.path(dir, "dfLL.RData"))
size <- 20
pChimp <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("ChimpBrain Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/real_datasets/GSE100505/mode_gcbias=True/posttype=gibbs_npost=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
pMouse <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("MouseMuscle Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

# %%
dir <- "environment/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLL.RData"))
size <- 20
pBrNorm <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimNorm Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

# %%
dir <- "environment/brain_sim_nodtu/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLLTPM.RData"))
size <- 20
pBrNorm <- ggplot(dfTPMLFCDist, aes(x=log2(Value), fill = Type, colour = Type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimNorm Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

dir <- "environment/brain_sim_nodtu_lowfc/mode=gc_bias/post_type=gibbs_nrep=100_tf=100/comp_trees"
load(file.path(dir, "dfLLTPM.RData"))
size <- 20
pBrLow <- ggplot(dfTPMLFCDist, aes(x=log2(Value), fill = Type, colour = Type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("BrSimLow Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

# dir <- "environment/Chimp/mode=gcbias/post_type=gibbs_nrep=100_tf=100/tree_analysis"
# load(file.path(dir, "dfLL.RData"))
# size <- 20
# pChimp <- ggplot(dfLFC, aes(x=log2(LFC), fill = type, colour = type)) + 
#     geom_density(position = "dodge", alpha=0.1) +
#     theme_bw() +
#     labs(fill="Type", color="Type") +
#     xlab(TeX("$log_{2}$(Value of Metric)")) +
#     ggtitle("ChimpBrain Dataset") +
#     theme(axis.title = element_text(size = size),
#     plot.title = element_text(size = size + 1, hjust=0.5),
#     axis.text = element_text(size = size),
#     legend.text = element_text(size = size),
#     legend.title = element_text(size = size))

dir <- "environment/real_datasets/GSE100505/mode_gcbias=True/posttype=gibbs_npost=100_tf=100/comp_trees"
load(file.path(dir, "dfLLTPM.RData"))
size <- 20
pMouse <- ggplot(dfTPMLFCDist, aes(x=log2(Value), fill = Type, colour = Type)) + 
    geom_density(position = "dodge", alpha=0.1) +
    theme_bw() +
    labs(fill="Type", color="Type") +
    xlab(TeX("$log_{2}$(Value of Metric)")) +
    ggtitle("MouseMuscle Dataset") +
    theme(axis.title = element_text(size = size),
    plot.title = element_text(size = size + 1, hjust=0.5),
    axis.text = element_text(size = size),
    legend.text = element_text(size = size),
    legend.title = element_text(size = size))

# %%
options(repr.plot.width=20, repr.plot.height=10)
ggarrange(pBrNorm,pBrLow,pMouse, common.legend=T)
# Out:
# Warning message:
# "Width not defined
# ℹ Set with `position_dodge(width = ...)`"
# Warning message:
# "Width not defined
# ℹ Set with `position_dodge(width = ...)`"
# Warning message:
# "Width not defined
# ℹ Set with `position_dodge(width = ...)`"
# Warning message:
# "Width not defined
# ℹ Set with `position_dodge(width = ...)`"
# plot without title
